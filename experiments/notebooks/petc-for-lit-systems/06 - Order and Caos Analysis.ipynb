# %%
# %load_ext autoreload
# %autoreload 2

from Utils import Notebook

from engine import Engine

Notebook.setup()
# Out:
#         <style>
#           @import url('https://fonts.googleapis.com/css2?family=JetBrains+Mono&display=swap');
#
#           body {
#             font-family: 'JetBrains Mono', -apple-system, BlinkMacSystemFont,
#                          'Segoe WPC', 'Segoe UI', system-ui, 'Ubuntu',
#                          'Droid Sans', sans-serif;
#             line-height: 1.67;
#           }
#         </style>
# LaTeX has been enabled for text rendering.

# %% [markdown]
# ### Definição da Planta

# %%
eng = Engine()
eng.load_system("../experiments/data/sys-01.json")

# %%
eng.load_sim(0.01, 10.0)

# %%
eng.open_loop(10.0)

# %%
# No seu notebook
import matplotlib.pyplot as plt
eng.open_loop(10.0)
results = eng.get_results()

plt.plot(results[:, 0])  # Plota a primeira variável de estado
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 4
#       2 import matplotlib.pyplot as plt
#       3 eng.open_loop(10.0)
# ----> 4 results = eng.get_results()
#       6 plt.plot(results[:, 0])  # Plota a primeira variável de estado
#       7 plt.show()
#
# File p:\Notebooks\Event-Based-Control\experiments\notebooks\petc-for-lit-systems\engine.py:8, in get_results(self)
#       4 import atexit
#       5 import numpy as np
# ----> 8 class Engine:
#       9   def __init__(self, dll_path="../../../core/dll/petc_for_lit_systems.dll"):
#      10     self.dll_path = os.path.abspath(dll_path)
#
# RuntimeError: A dimensão do estado é 0. O sistema foi carregado corretamente com loadSystem?
